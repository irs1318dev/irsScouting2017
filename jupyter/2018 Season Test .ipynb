# %%
import sys
import os
import re

import pandas as pd
import sqlalchemy as sa

# %%
# Import scouting system packages
import server.scouting.output as out
from server.model.event import EventDal

# %%
# Get a database connection
connection_string = ('postgresql://irs1318:irs1318'
                     '@localhost:5432/scouting')
engine = sa.create_engine(connection_string)
conn = engine.connect()

# %%
# Set Current Event
current_event = "turing"
EventDal.set_current_event(current_event)

# %%
col_name= 'placeGears'
new_name= 'placeCubeSwitch'
table_name = 'public.tasks'

sql_update= sa.text("UPDATE" + table_name + "," +
                    "SET name =" + new_name + "," +
                    "WHERE name =" + col_name+ ";")

# %%
# Get Measures Dataframe
sql_measures = sa.text(
    "SELECT events.name AS event, matches.name AS match, levels.name AS level, dates.name AS date, "
    "teams.name AS team, alliances.name AS alliance, "
    "stations.name AS station, phases.name AS phase, actors.name AS actor, tasks.name AS task, "
    "measures.capability AS capability, measures.successes as successes, measures.attempts AS attempts, "
    "measures.cycle_times as cycle_times, measuretypes.name AS measuretype, reasons.name AS reason, "
    "attempts.name AS attempt "
    "FROM ((((((((((((measures FULL OUTER JOIN teams ON measures.team_id=teams.id) "
    "LEFT JOIN events ON measures.event_id=events.id) "
    "LEFT JOIN matches ON measures.match_id=matches.id) "
    "LEFT JOIN levels ON measures.level_id=levels.id) "
    "LEFT JOIN dates ON measures.date_id=dates.id) "
    "LEFT JOIN alliances ON measures.alliance_id=alliances.id) "
    "LEFT JOIN stations ON measures.station_id=stations.id) "
    "LEFT JOIN phases ON measures.phase_id=phases.id) "
    "LEFT JOIN actors ON measures.actor_id=actors.id) "
    "LEFT JOIN tasks ON measures.task_id=tasks.id) "
    "LEFT JOIN reasons ON measures.reason_id=reasons.id) "
    "LEFT JOIN measuretypes ON measures.measuretype_id=measuretypes.id) "
    "LEFT JOIN attempts ON measures.attempt_id=attempts.id "
    "WHERE events.name='" + current_event + "';")
measures = pd.read_sql(sql_measures, conn)
measures
# Out:
#        event  match level                 date  team alliance station   phase  \
# 0     turing  001-q  qual  2017-04-20T08:30:00  1983     blue       2    auto
# 1     turing  001-q  qual  2017-04-20T08:30:00  1983     blue       2    auto
# 2     turing  003-q  qual  2017-04-20T08:46:00   948      red       2    auto
# 3     turing  003-q  qual  2017-04-20T08:46:00  6431      red       3    auto
# 4     turing  001-q  qual  2017-04-20T08:30:00  1983     blue       2  teleop
# 5     turing  001-q  qual  2017-04-20T08:30:00  1983     blue       2  teleop
# 6     turing  002-q  qual  2017-04-20T08:38:00  2761     blue       2    auto
# 7     turing  002-q  qual  2017-04-20T08:38:00  2761     blue       2    auto
# 8     turing  002-q  qual  2017-04-20T08:38:00  2761     blue       2  teleop
# 9     turing  002-q  qual  2017-04-20T08:38:00  2990     blue       3    auto
# 5465  turing  111-q  qual  2017-04-21T18:12:00  1983      red       1  finish
# 5466  turing  112-q  qual  2017-04-21T18:20:00  3794     blue       1  teleop
# 5467  turing  112-q  qual  2017-04-21T18:20:00   399      red       3  finish
# 5468  turing  112-q  qual  2017-04-21T18:20:00  3006     blue       3  teleop
# 5469  turing  112-q  qual  2017-04-21T18:20:00  3794     blue       1  teleop
# 5470  turing  112-q  qual  2017-04-21T18:20:00   108      red       1  finish
# 5471  turing  112-q  qual  2017-04-21T18:20:00  3794     blue       1  finish
# 5472  turing  112-q  qual  2017-04-21T18:20:00  2102      red       2  teleop
# 5473  turing  112-q  qual  2017-04-21T18:20:00   108      red       1  finish
# 5474  turing  112-q  qual  2017-04-21T18:20:00   399      red       3  finish
# 5475  turing  112-q  qual  2017-04-21T18:20:00  1287     blue       2  teleop
# 5476  turing  112-q  qual  2017-04-21T18:20:00  3006     blue       3  finish
# 5477  turing  112-q  qual  2017-04-21T18:20:00  1287     blue       2  finish
# 5478  turing  112-q  qual  2017-04-21T18:20:00   399      red       3  teleop
#
#       actor                task  capability  successes  attempts  cycle_times  \
# 0     robot           placeGear           0          0         1            0
# 1     robot            holdGear           0          1         1            0
# 2     robot        moveBaseline           0          1         1            0
# 3     robot        moveBaseline           0          1         1            0
# 4     robot           placeGear           0          2         2            0
# 5     robot  pickupGearRetrival           0          1         1            0
# 6     robot            holdGear           0          0         0            0
# 7     robot           placeGear           0          0         0            0
# 8     robot  pickupGearRetrival           0          0         0            0
# 9     robot     shootHighBoiler           0          0         0            0
# 10    robot    startingLocation           2          0         0            0
# 11    robot        moveBaseline           0          1         1            0
# 12    robot    startingLocation           2          0         0            0
# 13    robot    startingLocation           2          0         0            0
# 14    robot            holdGear           0          1         1            0
# 15    robot    startingLocation           3          0         0            0
# 16    robot            holdGear           0          1         1            0
# 17    robot            holdGear           0          1         1            0
# 18    robot           placeGear           0          0         1            0
# 19    robot            holdGear           0          1         1            0
# 20    robot        moveBaseline           0          1         1            0
# 21    robot        moveBaseline           0          0         1            0
# 22    robot           placeGear           0          0         0            0
# 23    robot            holdGear           0          1         1            0
# 24    robot           placeGear           0          1         1            0
# 25    robot            holdGear           0          1         1            0
# 26    robot           placeGear           0          3         3            0
# 27    robot  pickupGearRetrival           0          1         1            0
# 28    robot        moveBaseline           0          1         1            0
# 29    robot  pickupGearRetrival           0          1         1            0
# ...     ...                 ...         ...        ...       ...          ...
# 5449  robot           climbRope           0          5         5            0
# 5450  robot        pushTouchPad           0          1         1            0
# 5451  robot        pushTouchPad           0          1         1            0
# 5452  robot     pickupGearFloor           0          0         0            0
# 5453  robot           placeGear           0          0         1            0
# 5454  robot  pickupGearRetrival           0          0         0            0
# 5455  robot  pickupGearRetrival           0          0         0            0
# 5456  robot        moveBaseline           0          1         1            0
# 5457  robot            holdGear           0          1         1            0
# 5458  robot            holdGear           0          1         1            0
# 5459  robot  pickupGearRetrival           0          1         1            0
# 5460  robot  pickupGearRetrival           0          1         1            0
# 5461  robot  pickupGearRetrival           0          1         1            0
# 5462  robot           placeGear           0          1         2            0
# 5463  robot           placeGear           0          4         4            0
# 5464  robot           placeGear           0          4         5            0
# 5465  robot            disabled           0          1         1            0
# 5466  robot           placeGear           0          1         1            0
# 5467  robot           climbRope           0          4         4            0
# 5468  robot      defendMovement           0          3         3            0
# 5469  robot      defendMovement           0          1         1            0
# 5470  robot           climbRope           0          8         8            0
# 5471  robot            disabled           0          0         0            0
# 5472  robot      defendMovement           0          1         1            0
# 5473  robot        pushTouchPad           0          1         1            0
# 5474  robot        pushTouchPad           0          1         1            0
# 5475  robot  pickupGearRetrival           0          1         1            0
# 5476  robot        pushTouchPad           0          1         1            0
# 5477  robot        pushTouchPad           0          0         1            0
# 5478  robot     pickupGearFloor           0          1         1            0
#
#      measuretype reason  attempt
# 0        boolean     na  summary
# 1        boolean     na  summary
# 2        boolean     na  summary
# 3        boolean     na  summary
# 4          count     na  summary
# 5        boolean     na  summary
# 6        boolean     na  summary
# 7        boolean     na  summary
# 8        boolean     na  summary
# 9          count     na  summary
# 10          enum     na  summary
# 11       boolean     na  summary
# 12          enum     na  summary
# 13          enum     na  summary
# 14       boolean     na  summary
# 15          enum     na  summary
# 16       boolean     na  summary
# 17       boolean     na  summary
# 18       boolean     na  summary
# 19       boolean     na  summary
# 20       boolean     na  summary
# 21       boolean     na  summary
# 22       boolean     na  summary
# 23       boolean     na  summary
# 24       boolean     na  summary
# 25       boolean     na  summary
# 26         count     na  summary
# 27       boolean     na  summary
# 28       boolean     na  summary
# 29       boolean     na  summary
# ...          ...    ...      ...
# 5449       count     na  summary
# 5450     boolean     na  summary
# 5451     boolean     na  summary
# 5452     boolean     na  summary
# 5453     boolean     na  summary
# 5454     boolean     na  summary
# 5455     boolean     na  summary
# 5456     boolean     na  summary
# 5457     boolean     na  summary
# 5458     boolean     na  summary
# 5459     boolean     na  summary
# 5460     boolean     na  summary
# 5461     boolean     na  summary
# 5462       count     na  summary
# 5463       count     na  summary
# 5464       count     na  summary
# 5465     boolean     na  summary
# 5466       count     na  summary
# 5467       count     na  summary
# 5468       count     na  summary
# 5469       count     na  summary
# 5470       count     na  summary
# 5471     boolean     na  summary
# 5472       count     na  summary
# 5473     boolean     na  summary
# 5474     boolean     na  summary
# 5475     boolean     na  summary
# 5476     boolean     na  summary
# 5477     boolean     na  summary
# 5478     boolean     na  summary
#
# [5479 rows x 17 columns]
