# %% [markdown]
# ## Notebook Setup

# %% [markdown]
# ### Imports
# * **Run this cell immediately after opening the notebook by placing the cursor in the cell and hitting `SHIFT + ENTER`.**
# * Otherwise, leave this cell alone

# %%
# Imports for telling Python where to find IRScout Python modules
import sys
import os
import re
sys.path.append('..\Server')

# Set Current working directory to irsScouting2017\Server
ptn = re.compile("jupyter$")
if ptn.search(os.getcwd()) is not None:
    os.chdir("..\Server")
os.getcwd()

# IRScout Python Modules
import scouting.output as out
from scouting.event import EventDal

# Use the Bokeh plotting package
import bokeh.charts as bc
import bokeh.charts.attributes as bca
os.environ["BOKEH_RESOURCES"] = "inline"
bc.output_notebook()

# Other useful modules
import pandas as pd
import sqlalchemy as sa

# Get a database connection
connection_string = ('postgresql://irs1318:irs1318'
                     '@localhost:5432/scouting')
engine = sa.create_engine(connection_string)
conn = engine.connect()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b3304801-c1ab-471d-93d9-d4300ec60c93">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Set Defaults
# * **Next, set `current_event` to the applicable FIRST API event code and run this cell.**

# %%
# Set Chart Size
bc.defaults.height = 300
bc.defaults.width = 1200

# Set Current Event
current_event = "turing"
EventDal.set_current_event(current_event)
EventDal.get_current_event()
# Out:
# u'turing'

# %% [markdown]
# ### Export Excel Ranking File
# * Run this cell to export the rankings spreadsheet.

# %%
fpath = out.get_Path("Report")
out.get_report(fpath)

# %% [markdown]
# ### Get a Dataframe Containing all Measures

# %%
# Get Measures Dataframe
sql_measures = sa.text(
    "SELECT events.name AS event, matches.name AS match, levels.name AS level, dates.name AS date, "
    "teams.name AS team, alliances.name AS alliance, "
    "stations.name AS station, phases.name AS phase, actors.name AS actor, tasks.name AS task, "
    "measures.capability AS capability, measures.successes as successes, measures.attempts AS attempts, "
    "measures.cycle_times as cycle_times, measuretypes.name AS measuretype, reasons.name AS reason, "
    "attempts.name AS attempt "
    "FROM ((((((((((((measures FULL OUTER JOIN teams ON measures.team_id=teams.id) "
    "LEFT JOIN events ON measures.event_id=events.id) "
    "LEFT JOIN matches ON measures.match_id=matches.id) "
    "LEFT JOIN levels ON measures.level_id=levels.id) "
    "LEFT JOIN dates ON measures.date_id=dates.id) "
    "LEFT JOIN alliances ON measures.alliance_id=alliances.id) "
    "LEFT JOIN stations ON measures.station_id=stations.id) "
    "LEFT JOIN phases ON measures.phase_id=phases.id) "
    "LEFT JOIN actors ON measures.actor_id=actors.id) "
    "LEFT JOIN tasks ON measures.task_id=tasks.id) "
    "LEFT JOIN reasons ON measures.reason_id=reasons.id) "
    "LEFT JOIN measuretypes ON measures.measuretype_id=measuretypes.id) "
    "LEFT JOIN attempts ON measures.attempt_id=attempts.id "
    "WHERE events.name='" + current_event + "';")
measures = pd.read_sql(sql_measures, conn)
measures.query("task == 'shootHighBoiler'").query("phase == 'auto' or phase == 'teleop'")
#measures.query("task == 'climbRope' and phase == 'finish'")
# Out:
#        event  match level                 date  team alliance station   phase  \
# 9     turing  002-q  qual  2017-04-20T08:38:00  2990     blue       3    auto
# 84    turing  005-q  qual  2017-04-20T09:02:00  1165      red       3    auto
# 128   turing  004-q  qual  2017-04-20T08:54:00   108     blue       2  teleop
# 217   turing  006-q  qual  2017-04-20T09:10:00  1595     blue       2    auto
# 295   turing  008-q  qual  2017-04-20T09:26:00  3937     blue       1  teleop
# 368   turing  009-q  qual  2017-04-20T09:34:00  2907     blue       3    auto
# 382   turing  010-q  qual  2017-04-20T09:42:00   283     blue       3    auto
# 399   turing  012-q  qual  2017-04-20T09:58:00  1595      red       3    auto
# 413   turing  012-q  qual  2017-04-20T09:58:00  2102      red       2    auto
# 448   turing  012-q  qual  2017-04-20T09:58:00  4586     blue       3  teleop
# 462   turing  012-q  qual  2017-04-20T09:58:00  2352     blue       2    auto
# 463   turing  012-q  qual  2017-04-20T09:58:00  1595      red       3  teleop
# 486   turing  012-q  qual  2017-04-20T09:58:00  2352     blue       2  teleop
# 487   turing  013-q  qual  2017-04-20T10:06:00  2761     blue       1    auto
# 496   turing  013-q  qual  2017-04-20T10:06:00  1983     blue       2    auto
# 529   turing  014-q  qual  2017-04-20T10:14:00  1884      red       3  teleop
# 559   turing  016-q  qual  2017-04-20T10:30:00  5104     blue       1    auto
# 566   turing  016-q  qual  2017-04-20T10:30:00  4587     blue       3    auto
# 567   turing  016-q  qual  2017-04-20T10:30:00  3219     blue       2    auto
# 568   turing  016-q  qual  2017-04-20T10:30:00  3219     blue       2  teleop
# 620   turing  014-q  qual  2017-04-20T10:14:00  2046     blue       2    auto
# 623   turing  014-q  qual  2017-04-20T10:14:00  2046     blue       2  teleop
# 640   turing  016-q  qual  2017-04-20T10:30:00  1296      red       2    auto
# 673   turing  014-q  qual  2017-04-20T10:14:00    16     blue       1    auto
# 774   turing  018-q  qual  2017-04-20T10:46:00  3937      red       3    auto
# 843   turing  020-q  qual  2017-04-20T11:02:00  1323     blue       2  teleop
# 891   turing  020-q  qual  2017-04-20T11:02:00  1323     blue       2    auto
# 916   turing  021-q  qual  2017-04-20T11:10:00  2990      red       3    auto
# 959   turing  021-q  qual  2017-04-20T11:10:00  2990      red       3  teleop
# 1058  turing  025-q  qual  2017-04-20T11:42:00  4586     blue       2    auto
# ...      ...    ...   ...                  ...   ...      ...     ...     ...
# 2584  turing  053-q  qual  2017-04-21T08:32:00  2102      red       1    auto
# 2607  turing  057-q  qual  2017-04-21T09:04:00   108      red       3  teleop
# 2624  turing  056-q  qual  2017-04-21T08:56:00  6225      red       2    auto
# 2643  turing  054-q  qual  2017-04-21T08:40:00  1540      red       1    auto
# 2689  turing  058-q  qual  2017-04-21T09:12:00  2046     blue       1    auto
# 2729  turing  055-q  qual  2017-04-21T08:48:00  2761      red       3    auto
# 2756  turing  058-q  qual  2017-04-21T09:12:00  2046     blue       1  teleop
# 2840  turing  061-q  qual  2017-04-21T09:36:00  2102     blue       1    auto
# 2843  turing  065-q  qual  2017-04-21T10:08:00  5829     blue       3  teleop
# 2850  turing  061-q  qual  2017-04-21T09:36:00  3019      red       1  teleop
# 2883  turing  063-q  qual  2017-04-21T09:52:00  4610      red       2    auto
# 2913  turing  060-q  qual  2017-04-21T09:28:00  1595      red       1    auto
# 2924  turing  060-q  qual  2017-04-21T09:28:00  1540     blue       3  teleop
# 2930  turing  063-q  qual  2017-04-21T09:52:00    16      red       3    auto
# 2948  turing  063-q  qual  2017-04-21T09:52:00  4610      red       2  teleop
# 2950  turing  065-q  qual  2017-04-21T10:08:00  1323      red       2    auto
# 2981  turing  069-q  qual  2017-04-21T10:40:00  1983      red       1    auto
# 3036  turing  062-q  qual  2017-04-21T09:44:00  2352      red       2    auto
# 3045  turing  063-q  qual  2017-04-21T09:52:00    16      red       3  teleop
# 3047  turing  064-q  qual  2017-04-21T10:00:00  2990     blue       2    auto
# 3056  turing  065-q  qual  2017-04-21T10:08:00  1323      red       2  teleop
# 3071  turing  060-q  qual  2017-04-21T09:28:00  1540     blue       3    auto
# 3158  turing  063-q  qual  2017-04-21T09:52:00  2907     blue       3    auto
# 3199  turing  065-q  qual  2017-04-21T10:08:00  5829     blue       3    auto
# 3209  turing  066-q  qual  2017-04-21T10:16:00  3937      red       1  teleop
# 3221  turing  066-q  qual  2017-04-21T10:16:00  3219     blue       3    auto
# 3225  turing  066-q  qual  2017-04-21T10:16:00  3937      red       1    auto
# 3304  turing  071-q  qual  2017-04-21T10:56:00    16      red       1  teleop
# 3310  turing  070-q  qual  2017-04-21T10:48:00   399     blue       3  teleop
# 3362  turing  071-q  qual  2017-04-21T10:56:00    16      red       1    auto
#
#       actor             task  capability  successes  attempts  cycle_times  \
# 9     robot  shootHighBoiler           0          0         0            0
# 84    robot  shootHighBoiler           0          1         1            0
# 128   robot  shootHighBoiler           0          1        10            0
# 217   robot  shootHighBoiler           0          1         1            0
# 295   robot  shootHighBoiler           0          0         4            0
# 368   robot  shootHighBoiler           0          0         1            0
# 382   robot  shootHighBoiler           0         10        10            0
# 399   robot  shootHighBoiler           0          1         9            0
# 413   robot  shootHighBoiler           0         14        14            0
# 448   robot  shootHighBoiler           0         22        22            0
# 462   robot  shootHighBoiler           0          7        10            0
# 463   robot  shootHighBoiler           0         17        26            0
# 486   robot  shootHighBoiler           0         16        36            0
# 487   robot  shootHighBoiler           0          0         2            0
# 496   robot  shootHighBoiler           0          0        10            0
# 529   robot  shootHighBoiler           0          1         1            0
# 559   robot  shootHighBoiler           0          0         0            0
# 566   robot  shootHighBoiler           0          1         1            0
# 567   robot  shootHighBoiler           0          0         8            0
# 568   robot  shootHighBoiler           0          1         1            0
# 620   robot  shootHighBoiler           0          4        10            0
# 623   robot  shootHighBoiler           0         85        96            0
# 640   robot  shootHighBoiler           0          0         0            0
# 673   robot  shootHighBoiler           0         11        21            0
# 774   robot  shootHighBoiler           0          0        10            0
# 843   robot  shootHighBoiler           0         35        35            0
# 891   robot  shootHighBoiler           0         24        24            0
# 916   robot  shootHighBoiler           0          1         6            0
# 959   robot  shootHighBoiler           0         14        19            0
# 1058  robot  shootHighBoiler           0          3         9            0
# ...     ...              ...         ...        ...       ...          ...
# 2584  robot  shootHighBoiler           0          1        10            0
# 2607  robot  shootHighBoiler           0          1        10            0
# 2624  robot  shootHighBoiler           0          0         0            0
# 2643  robot  shootHighBoiler           0          3         5            0
# 2689  robot  shootHighBoiler           0          1         1            0
# 2729  robot  shootHighBoiler           0          0        10            0
# 2756  robot  shootHighBoiler           0         15        15            0
# 2840  robot  shootHighBoiler           0          1         1            0
# 2843  robot  shootHighBoiler           0          0         0            0
# 2850  robot  shootHighBoiler           0          3        12            0
# 2883  robot  shootHighBoiler           0          0         0            0
# 2913  robot  shootHighBoiler           0          1        10            0
# 2924  robot  shootHighBoiler           0          1         7            0
# 2930  robot  shootHighBoiler           0         20        25            0
# 2948  robot  shootHighBoiler           0          0         0            0
# 2950  robot  shootHighBoiler           0          8         8            0
# 2981  robot  shootHighBoiler           0          0         3            0
# 3036  robot  shootHighBoiler           0          4        10            0
# 3045  robot  shootHighBoiler           0         68        85            0
# 3047  robot  shootHighBoiler           0          0        10            0
# 3056  robot  shootHighBoiler           0         39        39            0
# 3071  robot  shootHighBoiler           0          3        10            0
# 3158  robot  shootHighBoiler           0          0         3            0
# 3199  robot  shootHighBoiler           0          0        10            0
# 3209  robot  shootHighBoiler           0         15        27            0
# 3221  robot  shootHighBoiler           0          0         3            0
# 3225  robot  shootHighBoiler           0          3        10            0
# 3304  robot  shootHighBoiler           0         80        92            0
# 3310  robot  shootHighBoiler           0          0        17            0
# 3362  robot  shootHighBoiler           0         20        29            0
#
#      measuretype reason  attempt
# 9          count     na  summary
# 84         count     na  summary
# 128        count     na  summary
# 217        count     na  summary
# 295        count     na  summary
# 368        count     na  summary
# 382        count     na  summary
# 399        count     na  summary
# 413        count     na  summary
# 448        count     na  summary
# 462        count     na  summary
# 463        count     na  summary
# 486        count     na  summary
# 487        count     na  summary
# 496        count     na  summary
# 529        count     na  summary
# 559        count     na  summary
# 566        count     na  summary
# 567        count     na  summary
# 568        count     na  summary
# 620        count     na  summary
# 623        count     na  summary
# 640        count     na  summary
# 673        count     na  summary
# 774        count     na  summary
# 843        count     na  summary
# 891        count     na  summary
# 916        count     na  summary
# 959        count     na  summary
# 1058       count     na  summary
# ...          ...    ...      ...
# 2584       count     na  summary
# 2607       count     na  summary
# 2624       count     na  summary
# 2643       count     na  summary
# 2689       count     na  summary
# 2729       count     na  summary
# 2756       count     na  summary
# 2840       count     na  summary
# 2843       count     na  summary
# 2850       count     na  summary
# 2883       count     na  summary
# 2913       count     na  summary
# 2924       count     na  summary
# 2930       count     na  summary
# 2948       count     na  summary
# 2950       count     na  summary
# 2981       count     na  summary
# 3036       count     na  summary
# 3045       count     na  summary
# 3047       count     na  summary
# 3056       count     na  summary
# 3071       count     na  summary
# 3158       count     na  summary
# 3199       count     na  summary
# 3209       count     na  summary
# 3221       count     na  summary
# 3225       count     na  summary
# 3304       count     na  summary
# 3310       count     na  summary
# 3362       count     na  summary
#
# [106 rows x 17 columns]

# %% [markdown]
# ### Get Number of Completed Matches

# %%
# Set recent_matches to n to filter out all but the last n matches.
recent_matches= 12

select_recent_matches = sa.text(
    "with current AS (SELECT s.event, s.match, date from schedules sched, "
    "status s WHERE sched.event = s.event "
    "AND sched.match = s.match limit 1 ) "


    "SELECT * FROM ( "
    "SELECT row_number() over (partition by team order by sched.date desc) as r, "
    " sched.* from schedules sched, current c WHERE sched.event = c.event and sched.date <= c.date )"
    " row_schedule WHERE row_schedule.r <= " + str(
        recent_matches) + " ORDER by team, date desc")
df = pd.read_sql(select_recent_matches, conn)
num_matches = df[['team', 'level']].groupby('team').count()
num_matches.columns = ['matches']

# %% [markdown]
# ### Create and Save Gears Chart
# * This cell creates the gears chart and saves it to Server/web/data as a static, interactive html file.
#
# **TODO:** Add an event code and timestamp to gears chart file name.

# %%
# Create summary data frame for placing gears
gears_df = measures.query("task == 'placeGear'").query("phase == 'auto' or phase == 'teleop'").groupby('team').sum()
gears_df['average'] = gears_df['successes'] / num_matches['matches']
gears_df = gears_df.sort_values('average', ascending = False)

# Create gears chart in Bokeh
gears_chart = bc.Bar(gears_df, values = 'average', label = bca.cat(sort = False), legend = None, color = 'purple',
                    title = 'Average Gears Placed per Match', ylabel = "Gears Placed")
bc.output_file('web/data/gears_chart.html', mode = 'inline')
bc.show(gears_chart)
# Out:
# INFO:bokeh.core.state:Session output file 'web/data/gears_chart.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="196a4595-41bc-4fce-a570-4ac74a09600b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("196a4595-41bc-4fce-a570-4ac74a09600b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("196a4595-41bc-4fce-a570-4ac74a09600b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '196a4595-41bc-4fce-a570-4ac74a09600b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0612e70f-bd70-410e-9c37-91ae763417ef":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"948"}],"color":["purple"],"fill_alpha":[0.8],"height":[3.5],"index":["948"],"label":[{"index":"948"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["948"],"y":[1.75]}},"id":"65118504-4094-49ac-adf8-de39de745aaa","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac199668-c575-4746-bd71-c8c6fb6d37c1","type":"Rect"},{"attributes":{"callback":null,"factors":["4206","1296","5802","3245","3997","4451","2147","4587","399","3737","5829","3937","4061","948","4468","108","1983","1523","6640","6554","5104","3103","2221","2473","4738","1318","5960","6417","1540","2352","4270","5417","3219","283","1595","2158","2907","4586","1323","6390","5677","1165","6413","6384","2761","5908","5124","3006","3337","2990","6431","1661","6225","2102","1884","2046","16","3476","5648","6038","5889","2723","3794","4135","4610","1287","3019"]},"id":"6bfe501c-5cd6-4fda-9f91-c41723545a76","type":"FactorRange"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"5960"}],"color":["purple"],"fill_alpha":[0.8],"height":[2.857142857142857],"index":["5960"],"label":[{"index":"5960"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["5960"],"y":[1.4285714285714286]}},"id":"18a57e73-0bc8-4a1c-b9b4-e4ad36798943","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"2184e594-2ecb-4e49-b7d4-e658dcb4018d","type":"ColumnDataSource"},"glyph":{"id":"0490576a-2da9-4ca8-9eab-73c326b3efb8","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"61be8bf3-6562-4485-939c-dd12e0a28e0f","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"35f724b5-fea4-4de3-bbeb-df9cb6543d58","type":"ColumnDataSource"},"glyph":{"id":"849a5840-813a-4eb5-8770-21bb62cd7cc5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b8ba6cb0-60a4-4e9d-b4f8-25bac7391b55","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"1296"}],"color":["purple"],"fill_alpha":[0.8],"height":[4.5],"index":["1296"],"label":[{"index":"1296"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1296"],"y":[2.25]}},"id":"3fbb97be-dd04-42d3-861b-eccc17dadcaf","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"de133d35-dc9e-46fe-9c2b-cdb6a26d2d6c","type":"ColumnDataSource"},"glyph":{"id":"96328228-47e4-47c7-8981-2d1e017350af","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"24daf8d2-6096-4779-977b-7296e40293f7","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"4135"}],"color":["purple"],"fill_alpha":[0.8],"height":[1.1666666666666667],"index":["4135"],"label":[{"index":"4135"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["4135"],"y":[0.5833333333333334]}},"id":"32c236b0-88d3-4c02-928a-138de214e069","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"b71cc80c-7eb8-43a6-b86e-5f6b41af81be","type":"ColumnDataSource"},"glyph":{"id":"0c38b9b4-437f-40ac-8b0f-da5a2af3ea86","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b9f10b7d-2349-4c22-99db-77a04c6e3f8b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"84f0c67b-e259-43e4-a2a2-75963c1d046d","type":"Co ...

# %%
# Create summary data frame for climbing rope
climbs_df = measures.query("task == 'climbRope'").query("phase == 'finish'").groupby('team').count()
climbs_df['average'] = climbs_df['successes'] / num_matches['matches']
climbs_df = climbs_df.sort_values('average', ascending = False)

# Create gears chart in Bokeh
climb_chart = bc.Bar(climbs_df, values = 'average', label = bca.cat(sort = False), legend = None, color = 'DarkGoldenRod',
                    title = 'Total Times Climbed', ylabel = "Times Climbed")
bc.output_file('web/data/climb_chart.html', mode = 'inline')
bc.show(climb_chart)
# Out:
# INFO:bokeh.core.state:Session output file 'web/data/climb_chart.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="584b33be-e715-4ed4-8358-8454dd2e5e48"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("584b33be-e715-4ed4-8358-8454dd2e5e48").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("584b33be-e715-4ed4-8358-8454dd2e5e48");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '584b33be-e715-4ed4-8358-8454dd2e5e48' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eec2c857-60be-4694-9478-1d61a18bbd28":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"6384"}],"color":["DarkGoldenRod"],"fill_alpha":[0.8],"height":[0.3333333333333333],"index":["6384"],"label":[{"index":"6384"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["6384"],"y":[0.16666666666666666]}},"id":"3ec5ee37-c5b5-43cc-8f16-eac40f1f88a5","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"1318"}],"color":["DarkGoldenRod"],"fill_alpha":[0.8],"height":[0.8571428571428571],"index":["1318"],"label":[{"index":"1318"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1318"],"y":[0.42857142857142855]}},"id":"1bc4825f-af76-4463-ba12-a184f9c40de6","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"5908"}],"color":["DarkGoldenRod"],"fill_alpha":[0.8],"height":[1.0],"index":["5908"],"label":[{"index":"5908"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["5908"],"y":[0.5]}},"id":"0135b6f1-e37b-4602-9ca8-0b349e1d8fab","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"79a47fce-f031-4fb5-a463-0e724228984d","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"06967e4a-f7df-49ed-963f-01df2f349a22","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"132ebe0e-6ba9-4259-8243-af3968ffa69f","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"108"}],"color":["DarkGoldenRod"],"fill_alpha":[0.8],"height":[1.0],"index":["108"],"label":[{"index":"108"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["108"],"y":[0.5]}},"id":"9d729e1e-23a3-4165-8cde-e6d285beb3ea","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"510550d7-d039-48af-b2e2-15b763cc9334","type":"Rect"},{"attributes":{},"id":"99b582ef-ec0f-4848-9387-12cb752e8afb","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"a63cfc4a-fb79-49ea-8201-648bf8669af9","type":"ColumnDataSource"},"glyph":{"id":"5179313c-3f50-4dd9-bb84-50e525910474","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"263752d3-1b56-4f03-8bf2-0ab46ac9482b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"4135"}],"color":["DarkGoldenRod"],"fill_alpha":[0.8],"height":[1.0],"index":["4135"],"label":[{"index":"4135"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["4135"],"y":[0.5]}},"id":"cc4562b1-d309-4523-adbe-7f197b07e237","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color" ...

# %%
# Create summary data frame for shooting fuel
fuel_df = measures.query("task == 'shootHighBoiler'").query("phase == 'auto' or phase == 'teleop'").groupby('team').sum()
fuel_df['average'] = fuel_df['successes'] / num_matches['matches']
fuel_df = fuel_df.sort_values('average', ascending = False)

# Create gears chart in Bokeh
fuel_chart = bc.Bar(fuel_df, values = 'average', label = bca.cat(sort = False), legend = None, color = 'DarkRed',
                    title = 'Average Fuel Shot per Match', ylabel = "Number of Shots")
bc.output_file('web/data/fuel_chart.html', mode = 'inline')
bc.show(fuel_chart)
# Out:
# INFO:bokeh.core.state:Session output file 'web/data/fuel_chart.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2f272a49-80ac-4ee3-8ea4-b5a1ffc6c77f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2f272a49-80ac-4ee3-8ea4-b5a1ffc6c77f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2f272a49-80ac-4ee3-8ea4-b5a1ffc6c77f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2f272a49-80ac-4ee3-8ea4-b5a1ffc6c77f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0183aa12-43c2-4495-a7af-b8e5cf863a9d":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"3937"}],"color":["DarkRed"],"fill_alpha":[0.8],"height":[20.5],"index":["3937"],"label":[{"index":"3937"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["3937"],"y":[10.25]}},"id":"02ccead1-4b92-499e-9d9e-8237b5fe9a48","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"dd181e8d-3ef7-4da3-aa4a-14a8a51064bf","subtype":"Chart","type":"Plot"},"ticker":{"id":"ddf7e278-7242-448e-bf4a-c13103695191","type":"BasicTicker"}},"id":"2edc6f75-022d-4f54-87f7-3fc373c54751","type":"Grid"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"1296"}],"color":["DarkRed"],"fill_alpha":[0.8],"height":[0.0],"index":["1296"],"label":[{"index":"1296"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["1296"],"y":[0.0]}},"id":"d50b9ced-0bc0-4bcc-b0b8-c5b0a6911704","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"acf27c63-a9ab-4eff-becc-addc07fb45f1","type":"ColumnDataSource"},"glyph":{"id":"44336bd3-4e41-497a-910a-39def8401479","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2a90da58-13d6-4b5a-a6f3-f43240a9feda","type":"GlyphRenderer"},{"attributes":{},"id":"f7a0cf8d-4b20-41cb-9713-605586cfb578","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"ceb6fd31-10d0-43e2-8a99-9229fa16c4ff","type":"ColumnDataSource"},"glyph":{"id":"9e23aaf5-0127-47a9-bbbd-6f45d65c8689","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7a808cba-eed7-43a5-a5a0-3e1da434568d","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"dd181e8d-3ef7-4da3-aa4a-14a8a51064bf","subtype":"Chart","type":"Plot"}},"id":"f2dcd183-dad5-4030-ad25-745cbe1f8389","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"33567524-94e6-430c-ac1b-8bd1691c8f0e","type":"ColumnDataSource"},"glyph":{"id":"f22c1f57-4328-4a82-95e8-7c98a8c97121","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"4d9865da-54b0-459b-832d-bf1ab5226d90","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5fe90567-4cc8-49c6-b8cf-9a39d4d4ba1a","type":"Rect"},{"attributes":{"data_source":{"id":"19be9914-d7a2-47a1-899e-96da62650b5a","type":"ColumnDataSource"},"glyph":{"id":"7aee38f1-6416-4dd8-a885-2b4c3388a6f5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"75f2bcf0-fd8f-407c-b2b0-1675d64c3f64","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"89c525b6-daf1-48b9-bcae-9c99a3d4012b","type":"ColumnDataSource"},"glyph":{"id":"e0e78fa6-e47d-486a-afee-fb392f394012","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5e1daf02-21e3-49a6-9cf3-c8c103e28220","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"463d367c-19df-4b60-9ff9-d71e3e5e01f0","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"index":"399"}],"color":["DarkRed"],"fill_alpha":[0.8],"height":[0.0],"index":["399"],"label":[{"index":"399"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["399"],"y":[0.0]}},"id":"21385807-64ef-418a-a900-b322d01a1e96","type":"ColumnDataSource"},{"attributes":{"da ...
