# %% [markdown]
# # Measure Viewer -- IRS Scouting System
# When running this notebook for the first time, select *Cell->Run All* from the Notebook menu.

# %%
# Cell 1
import json

import IPython.display
import ipywidgets as widgets
import pandas
import sqlalchemy

import server.model.connection as sm_connection
import server.model.event as sm_event
import server.model.firstapi as sm_firstapi
import server.season.s2018.api_measures as s2018_api
import server.view.excel as sv_excel
import server.view.dataframes as sv_dataframes

# %%
# Cell 2

def get_measures(match="001-q"):
    conn = sm_connection.engine.connect()
    event_id = sm_event.EventDal.get_current_event()[0]
    sql = sqlalchemy.text("SELECT events.name, matches.name AS match, alliances.name AS alliance, "
                          "stations.name AS station, teams.name AS team, phases.name AS phase, "
                          "tasks.name AS task, measures.attempts, measures.successes, "
                          "measures.cycle_times, measures.capability, task_options.option_name "
                          "FROM measures "
                          "INNER JOIN tasks ON measures.task_id = tasks.id "
                          "INNER JOIN teams ON measures.team_id = teams.id "
                          "INNER JOIN matches ON measures.match_id = matches.id "
                          "INNER JOIN phases ON measures.phase_id = phases.id "
                          "INNER JOIN alliances ON measures.alliance_id = alliances.id "
                          "INNER JOIN stations ON measures.station_id = stations.id "
                          "INNER JOIN events ON measures.event_id = events.id "
                          "LEFT JOIN task_options ON measures.capability = task_options.id "
                          "WHERE event_id = :evt_id AND matches.name = :mtch "
                          "ORDER BY alliances.name, stations.name, phases.name, tasks.name"
                          ";").bindparams(evt_id=event_id, mtch=match)
    measures_df = pandas.read_sql(sql, conn)
    conn.close()
    return measures_df


def run_cell(cell):
    jscript_cmd = "Jupyter.notebook.execute_cells([" + str(cell) + "])"
    IPython.display.display_javascript(IPython.display.Javascript(jscript_cmd))

    
match = "020-q"
df = None
match_txt = widgets.Text(description="Match", value=match)
match_button = widgets.Button(description="Show Measures")
IPython.display.display(widgets.HBox([match_txt, match_button]))


def show_measures(b):
    # IPython.display.clear_output()
    measures_output_cell = 3
    global match
    match = match_txt.value
    global df
    df = get_measures(match)
    run_cell(measures_output_cell)
    

match_button.on_click(show_measures)
# Out:
# HBox(children=(Text(value='020-q', description='Match'), Button(description='Show Measures', style=ButtonStyle…

# %%
# Cell 3
df
# Out:
#          name  match alliance station  team   phase                task  \
# 0   test_data  020-q     blue       1  4918    auto          closeHatch
# 1   test_data  020-q     blue       1  4918    auto           collision
# 2   test_data  020-q     blue       1  4918    auto        crossHabLine
# 3   test_data  020-q     blue       1  4918    auto            getHatch
# 4   test_data  020-q     blue       1  4918    auto            pickSide
# 5   test_data  020-q     blue       1  4918    auto           startItem
# 6   test_data  020-q     blue       1  4918  finish               climb
# 7   test_data  020-q     blue       1  4918  finish            fellOver
# 8   test_data  020-q     blue       1  4918  finish                temp
# 9   test_data  020-q     blue       1  4918  teleop           dropCargo
# 10  test_data  020-q     blue       1  4918  teleop           dropHatch
# 11  test_data  020-q     blue       1  4918  teleop            duration
# 12  test_data  020-q     blue       1  4918  teleop             getFoul
# 13  test_data  020-q     blue       1  4918  teleop   groundHatchPickup
# 14  test_data  020-q     blue       1  4918  teleop  pickupLoadingHatch
# 15  test_data  020-q     blue       1  4918  teleop        rocketCargo2
# 16  test_data  020-q     blue       1  4918  teleop        rocketCargo3
# 17  test_data  020-q     blue       1  4918  teleop        rocketHatch1
# 18  test_data  020-q     blue       2  4461    auto        crossHabLine
# 19  test_data  020-q     blue       2  4461    auto            getHatch
# 20  test_data  020-q     blue       2  4461    auto           startItem
# 21  test_data  020-q     blue       2  4461  finish               climb
# 22  test_data  020-q     blue       2  4461  finish            fellOver
# 23  test_data  020-q     blue       2  4461  finish         stuckOnPlat
# 24  test_data  020-q     blue       2  4461  teleop             csCargo
# 25  test_data  020-q     blue       2  4461  teleop             csHatch
# 26  test_data  020-q     blue       2  4461  teleop           dropCargo
# 27  test_data  020-q     blue       2  4461  teleop           dropHatch
# 28  test_data  020-q     blue       2  4461  teleop            duration
# 29  test_data  020-q     blue       2  4461  teleop   groundCargoPickup
# ..        ...    ...      ...     ...   ...     ...                 ...
# 70  test_data  020-q      red       2  3786    auto           startItem
# 71  test_data  020-q      red       2  3786  finish               climb
# 72  test_data  020-q      red       2  3786  teleop             csCargo
# 73  test_data  020-q      red       2  3786  teleop             csHatch
# 74  test_data  020-q      red       2  3786  teleop           dropCargo
# 75  test_data  020-q      red       2  3786  teleop           dropHatch
# 76  test_data  020-q      red       2  3786  teleop            duration
# 77  test_data  020-q      red       2  3786  teleop   groundCargoPickup
# 78  test_data  020-q      red       2  3786  teleop  pickupLoadingCargo
# 79  test_data  020-q      red       2  3786  teleop  pickupLoadingHatch
# 80  test_data  020-q      red       2  3786  teleop        rocketCargo1
# 81  test_data  020-q      red       2  3786  teleop        rocketCargo3
# 82  test_data  020-q      red       2  3786  teleop        rocketHatch3
# 83  test_data  020-q      red       3  1258    auto     crossCenterLine
# 84  test_data  020-q      red       3  1258    auto            pickSide
# 85  test_data  020-q      red       3  1258    auto           startItem
# 86  test_data  020-q      red       3  1258  finish               climb
# 87  test_data  020-q      red       3  1258  teleop             csCargo
# 88  test_data  020-q      red       3  1258  teleop             csHatch
# 89  test_data  020-q      red       3  1258  teleop           dropCargo
# 90  test_data  020-q      red       3  1258  teleop           dropHatch
# 91  test_data  020-q      red       3  1258  teleop            duration
# 92  test_data  020-q      red       3  1258  teleop             getFoul
# 93  test_data  020-q      red       3  1258  teleop   groundHatchPickup
# 94  test_data  020-q      red       3  1258  teleop  pickupLoadingCargo
# 95  test_data  020-q      red       3  1258  teleop  pickupLoadingHatch
# 96  test_data  020-q      red       3  1258  teleop        rocketCargo1
# 97  test_data  020-q      red       3  1258  teleop        rocketCargo2
# 98  test_data  020-q      red       3  1258  teleop        rocketHatch2
# 99  test_data  020-q      red       3  1258  teleop        rocketHatch3
#
#     attempts  successes  cycle_times  capability option_name
# 0          1          1            0           0        None
# 1          1          1            0           0        None
# 2          1          1            0           0        None
# 3          1          1            0           0        None
# 4          0          0            0        1480        Side
# 5          0          0            0        1483       Hatch
# 6          0          0            0        1613           1
# 7          1          1            0           0        None
# 8          1          1            0           0        None
# 9          2          2            0           0        None
# 10         1          1            0           0        None
# 11         3          1            0           0        None
# 12         2          2            0           0        None
# 13         1          1            0           0        None
# 14         1          1            0           0        None
# 15         2          2            0           0        None
# 16         0          0            0           0        None
# 17         1          1            0           0        None
# 18         1          1            0           0        None
# 19         1          1            0           0        None
# 20         0          0            0        1483       Hatch
# 21         0          0            0        1613           1
# 22         1          1            0           0        None
# 23         1          1            0           0        None
# 24         2          2            0           0        None
# 25         2          2            0           0        None
# 26         2          2            0           0        None
# 27         4          4            0           0        None
# 28         3          2            0           0        None
# 29         2          2            0           0        None
# ..       ...        ...          ...         ...         ...
# 70         0          0            0        1483       Hatch
# 71         0          0            0        1613           1
# 72         1          1            0           0        None
# 73         2          2            0           0        None
# 74         2          2            0           0        None
# 75         6          6            0           0        None
# 76         3          2            0           0        None
# 77         4          4            0           0        None
# 78         2          2            0           0        None
# 79         2          2            0           0        None
# 80         2          2            0           0        None
# 81         1          1            0           0        None
# 82         0          0            0           0        None
# 83         0          0            0           0        None
# 84         0          0            0        1481      Center
# 85         0          0            0        1482       Cargo
# 86         0          0            0        1613           1
# 87         3          3            0           0        None
# 88         1          1            0           0        None
# 89         0          0            0           0        None
# 90         3          3            0           0        None
# 91         3          3            0           0        None
# 92         2          2            0           0        None
# 93         1          1            0           0        None
# 94         2          2            0           0        None
# 95         4          4            0           0        None
# 96         2          2            0           0        None
# 97         2          2            0           0        None
# 98         3          3            0           0        None
# 99         1          1            0           0        None
#
# [100 rows x 12 columns]

# %%
df.query("phase=='auto'")
# Out:
#      name  match alliance station  team phase           task  attempts  \
# 0   waamv  004-q     blue       1  4579  auto       autoLine         1
# 1   waamv  004-q     blue       1  4579  auto  startPosition         0
# 7   waamv  004-q     blue       2  3219  auto       holdCube         1
# 8   waamv  004-q     blue       2  3219  auto  startPosition         0
# 16  waamv  004-q     blue       3  2929  auto       autoLine         1
# 17  waamv  004-q     blue       3  2929  auto       holdCube         1
# 21  waamv  004-q      red       1  3393  auto       autoLine         1
# 22  waamv  004-q      red       1  3393  auto  startPosition         0
# 26  waamv  004-q      red       2  3223  auto       autoLine         1
# 27  waamv  004-q      red       2  3223  auto       holdCube         1
# 28  waamv  004-q      red       2  3223  auto     pickupCube         0
# 29  waamv  004-q      red       2  3223  auto    placeSwitch         0
# 34  waamv  004-q      red       3  2046  auto       autoLine         1
# 35  waamv  004-q      red       3  2046  auto       holdCube         1
# 36  waamv  004-q      red       3  2046  auto     pickupCube         1
# 37  waamv  004-q      red       3  2046  auto     placeScale         1
# 38  waamv  004-q      red       3  2046  auto    placeSwitch         1
# 39  waamv  004-q      red       3  2046  auto  startPosition         0
#
#     successes  cycle_times  capability option_name
# 0           1            0           0        None
# 1           0            0        1253        Exch
# 7           1            0           0        None
# 8           0            0        1254      Center
# 16          1            0           0        None
# 17          1            0           0        None
# 21          1            0           0        None
# 22          0            0        1253        Exch
# 26          1            0           0        None
# 27          1            0           0        None
# 28          0            0           0        None
# 29          0            0           0        None
# 34          1            0           0        None
# 35          1            0           0        None
# 36          1            0           0        None
# 37          0            0           0        None
# 38          1            0           0        None
# 39          0            0        1254      Center
