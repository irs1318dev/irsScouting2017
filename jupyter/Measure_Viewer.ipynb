# %% [markdown]
# # Measure Viewer -- IRS Scouting System
# When running this notebook for the first time, select *Cell->Run All* from the Notebook menu.

# %%
# Cell 1
import json

import IPython.display
import ipywidgets as widgets
import pandas
import sqlalchemy

import server.model.connection as sm_connection
import server.model.event as sm_event
import server.model.firstapi as sm_firstapi
import server.season.s2018.api_measures as s2018_api
import server.view.excel as sv_excel
import server.view.dataframes as sv_dataframes

# %%
# Cell 2

def get_measures(match="001-q"):
    conn = sm_connection.engine.connect()
    event_id = sm_event.EventDal.get_current_event()[0]
    sql = sqlalchemy.text("SELECT events.name, matches.name AS match, alliances.name AS alliance, "
                          "stations.name AS station, teams.name AS team, phases.name AS phase, "
                          "tasks.name AS task, measures.attempts, measures.successes, "
                          "measures.cycle_times, measures.capability, task_options.option_name "
                          "FROM measures "
                          "INNER JOIN tasks ON measures.task_id = tasks.id "
                          "INNER JOIN teams ON measures.team_id = teams.id "
                          "INNER JOIN matches ON measures.match_id = matches.id "
                          "INNER JOIN phases ON measures.phase_id = phases.id "
                          "INNER JOIN alliances ON measures.alliance_id = alliances.id "
                          "INNER JOIN stations ON measures.station_id = stations.id "
                          "INNER JOIN events ON measures.event_id = events.id "
                          "LEFT JOIN task_options ON measures.capability = task_options.id "
                          "WHERE event_id = :evt_id AND matches.name = :mtch "
                          "ORDER BY alliances.name, stations.name, phases.name, tasks.name"
                          ";").bindparams(evt_id=event_id, mtch=match)
    measures_df = pandas.read_sql(sql, conn)
    conn.close()
    return measures_df


def run_cell(cell):
    jscript_cmd = "Jupyter.notebook.execute_cells([" + str(cell) + "])"
    IPython.display.display_javascript(IPython.display.Javascript(jscript_cmd))

    
match = "001-q"
df = None
match_txt = widgets.Text(description="Match", value=match)
match_button = widgets.Button(description="Show Measures")
IPython.display.display(widgets.HBox([match_txt, match_button]))


def show_measures(b):
    # IPython.display.clear_output()
    measures_output_cell = 3
    global match
    match = match_txt.value
    global df
    df = get_measures(match)
    run_cell(measures_output_cell)
    

match_button.on_click(show_measures)
# Out:
# A Jupyter Widget

# %%
# Cell 3
df
# Out:
#       name  match alliance station  team   phase            task  attempts  \
# 0   turing  003-q     blue       1  6952    auto        autoLine         1
# 1   turing  003-q     blue       1  6952    auto   startPosition         0
# 2   turing  003-q     blue       1  6952  teleop  pickupCubeZone         8
# 3   turing  003-q     blue       1  6952  teleop   placeExchange         5
# 4   turing  003-q     blue       1  6952  teleop     placeSwitch         4
# 5   turing  003-q     blue       2  7057    auto        autoLine         0
# 6   turing  003-q     blue       2  7057    auto        holdCube         1
# 7   turing  003-q     blue       2  7057    auto   startPosition         0
# 8   turing  003-q     blue       2  7057  finish        disabled         1
# 9   turing  003-q     blue       3  2630    auto        autoLine         1
# 10  turing  003-q     blue       3  2630    auto        holdCube         1
# 11  turing  003-q     blue       3  2630    auto     placeSwitch         1
# 12  turing  003-q     blue       3  2630    auto   startPosition         0
# 13  turing  003-q     blue       3  2630  finish       makeClimb         1
# 14  turing  003-q     blue       3  2630  teleop  pickupPlatform         5
# 15  turing  003-q     blue       3  2630  teleop    pickupPortal         1
# 16  turing  003-q     blue       3  2630  teleop      placeScale         6
# 17  turing  003-q      red       1  1806    auto        autoLine         1
# 18  turing  003-q      red       1  1806    auto       crossNull         0
# 19  turing  003-q      red       1  1806    auto        holdCube         1
# 20  turing  003-q      red       1  1806    auto      pickupCube         0
# 21  turing  003-q      red       1  1806    auto      placeScale         1
# 22  turing  003-q      red       1  1806    auto   startPosition         0
# 23  turing  003-q      red       1  1806  finish       makeClimb         1
# 24  turing  003-q      red       1  1806  teleop     pickupFloor         0
# 25  turing  003-q      red       1  1806  teleop  pickupPlatform         4
# 26  turing  003-q      red       1  1806  teleop    pickupPortal         1
# 27  turing  003-q      red       1  1806  teleop      placeScale         5
# 28  turing  003-q      red       2   364    auto        autoLine         1
# 29  turing  003-q      red       2   364    auto        holdCube         1
# 30  turing  003-q      red       2   364    auto      pickupCube         1
# 31  turing  003-q      red       2   364    auto     placeSwitch         2
# 32  turing  003-q      red       2   364    auto   startPosition         0
# 33  turing  003-q      red       2   364  finish       makeClimb         1
# 34  turing  003-q      red       2   364  finish    supportClimb         0
# 35  turing  003-q      red       2   364  teleop  pickupCubeZone         1
# 36  turing  003-q      red       2   364  teleop  pickupPlatform         4
# 37  turing  003-q      red       2   364  teleop   placeOpponent         3
# 38  turing  003-q      red       2   364  teleop      placeScale         2
# 39  turing  003-q      red       2   364  teleop     placeSwitch         0
# 40  turing  003-q      red       3  4561    auto        autoLine         1
# 41  turing  003-q      red       3  4561    auto        holdCube         1
# 42  turing  003-q      red       3  4561    auto   startPosition         0
# 43  turing  003-q      red       3  4561  teleop  pickupCubeZone         7
# 44  turing  003-q      red       3  4561  teleop   placeExchange         7
# 45  turing  003-q      red       3  4561  teleop      placeScale         1
#
#     successes  cycle_times  capability option_name
# 0           1            0           0        None
# 1           0            0        1253        Exch
# 2           8            0           0        None
# 3           5            0           0        None
# 4           4            0           0        None
# 5           0            0           0        None
# 6           1            0           0        None
# 7           0            0        1255       NonEx
# 8           1            0           0        None
# 9           1            0           0        None
# 10          1            0           0        None
# 11          1            0           0        None
# 12          0            0        1254      Center
# 13          0            0           0        None
# 14          5            0           0        None
# 15          1            0           0        None
# 16          6            0           0        None
# 17          1            0           0        None
# 18          0            0           0        None
# 19          1            0           0        None
# 20          0            0           0        None
# 21          0            0           0        None
# 22          0            0        1253        Exch
# 23          0            0           0        None
# 24          0            0           0        None
# 25          4            0           0        None
# 26          1            0           0        None
# 27          5            0           0        None
# 28          1            0           0        None
# 29          1            0           0        None
# 30          1            0           0        None
# 31          2            0           0        None
# 32          0            0        1254      Center
# 33          1            0           0        None
# 34          0            0           0        None
# 35          1            0           0        None
# 36          4            0           0        None
# 37          3            0           0        None
# 38          2            0           0        None
# 39          0            0           0        None
# 40          1            0           0        None
# 41          1            0           0        None
# 42          0            0        1255       NonEx
# 43          7            0           0        None
# 44          7            0           0        None
# 45          1            0           0        None

# %%
df.query("phase=='teleop'")
# Out:
#       name  match alliance station  team   phase            task  attempts  \
# 2   turing  003-q     blue       1  6952  teleop  pickupCubeZone         8
# 3   turing  003-q     blue       1  6952  teleop   placeExchange         5
# 4   turing  003-q     blue       1  6952  teleop     placeSwitch         4
# 14  turing  003-q     blue       3  2630  teleop  pickupPlatform         5
# 15  turing  003-q     blue       3  2630  teleop    pickupPortal         1
# 16  turing  003-q     blue       3  2630  teleop      placeScale         6
# 24  turing  003-q      red       1  1806  teleop     pickupFloor         0
# 25  turing  003-q      red       1  1806  teleop  pickupPlatform         4
# 26  turing  003-q      red       1  1806  teleop    pickupPortal         1
# 27  turing  003-q      red       1  1806  teleop      placeScale         5
# 35  turing  003-q      red       2   364  teleop  pickupCubeZone         1
# 36  turing  003-q      red       2   364  teleop  pickupPlatform         4
# 37  turing  003-q      red       2   364  teleop   placeOpponent         3
# 38  turing  003-q      red       2   364  teleop      placeScale         2
# 39  turing  003-q      red       2   364  teleop     placeSwitch         0
# 43  turing  003-q      red       3  4561  teleop  pickupCubeZone         7
# 44  turing  003-q      red       3  4561  teleop   placeExchange         7
# 45  turing  003-q      red       3  4561  teleop      placeScale         1
#
#     successes  cycle_times  capability option_name
# 2           8            0           0        None
# 3           5            0           0        None
# 4           4            0           0        None
# 14          5            0           0        None
# 15          1            0           0        None
# 16          6            0           0        None
# 24          0            0           0        None
# 25          4            0           0        None
# 26          1            0           0        None
# 27          5            0           0        None
# 35          1            0           0        None
# 36          4            0           0        None
# 37          3            0           0        None
# 38          2            0           0        None
# 39          0            0           0        None
# 43          7            0           0        None
# 44          7            0           0        None
# 45          1            0           0        None
