# %%
import sqlalchemy
import server.model.connection as smc

# %%
conn = smc.engine.connect()
# sql = sqlalchemy.text("SELECT * FROM measures WHERE "
#                       "event_id = 18193 "
#                       "AND match_id = 1 "
#                       "AND team_id = 948;")
sql = sqlalchemy.text("SELECT * FROM measures WHERE event_id = 18193;")
results = conn.execute(sql)

for row in results:
    print(row)
conn.close()
# Out:
# (18200, 18193, 1, 1, 2, 7, 3, 3, 4, 4, 3, 1, 1, 0, 1, 0, 0)
# (18200, 18193, 1, 1, 2, 7, 3, 3, 1, 4, 3, 1, 1, 0, 1, 1, 0)
# (18212, 18193, 1, 3, 3, 4278, 3, 3, 16, 4, 3, 1, 1, 0, 1, 1, 0)
# (18212, 18193, 1, 3, 3, 18213, 4, 3, 16, 4, 3, 1, 1, 0, 1, 1, 0)
# (18200, 18193, 1, 1, 2, 7, 3, 3, 4, 2, 4, 1, 1, 0, 2, 2, 0)
# (18200, 18193, 1, 1, 2, 7, 3, 3, 448, 4, 4, 1, 1, 0, 1, 1, 0)
# (18206, 18193, 1, 2, 2, 18209, 3, 3, 1, 4, 3, 1, 1, 0, 0, 0, 0)
# (18206, 18193, 1, 2, 2, 18209, 3, 3, 4, 4, 3, 1, 1, 0, 0, 0, 0)
# (18206, 18193, 1, 2, 2, 18209, 3, 3, 448, 4, 4, 1, 1, 0, 0, 0, 0)
# (18206, 18193, 1, 2, 2, 5134, 4, 3, 11, 2, 3, 1, 1, 0, 0, 0, 0)
# (18200, 18193, 1, 1, 2, 7, 3, 3, 15, 5, 3, 1, 1, 2, 0, 0, 0)
# (18200, 18193, 1, 1, 2, 7, 3, 3, 16, 4, 3, 1, 1, 0, 1, 1, 0)
# (18212, 18193, 1, 3, 2, 5120, 3, 3, 15, 5, 3, 1, 1, 2, 0, 0, 0)
# (18212, 18193, 1, 3, 3, 18213, 4, 3, 15, 5, 3, 1, 1, 2, 0, 0, 0)
# (18212, 18193, 1, 3, 2, 18214, 2, 3, 1, 4, 3, 1, 1, 0, 1, 1, 0)
# ...

# %%
conn.close()

# %%
len(task_options)
# Out:
# 103
