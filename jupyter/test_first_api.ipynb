# %%
import json
import server.model.firstapi as smf

# %%
sched = json.loads(smf.schedule("pncmp", "2017"))
sched
# Out:
# {'Schedule': [{'description': 'Qualification 1',
#    'field': 'Primary',
#    'matchNumber': 1,
#    'startTime': '2017-04-06T14:00:00',
#    'teams': [{'station': 'Red1', 'surrogate': False, 'teamNumber': 2910},
#     {'station': 'Red2', 'surrogate': False, 'teamNumber': 753},
#     {'station': 'Red3', 'surrogate': False, 'teamNumber': 488},
#     {'station': 'Blue1', 'surrogate': False, 'teamNumber': 4513},
#     {'station': 'Blue2', 'surrogate': False, 'teamNumber': 5295},
#     {'station': 'Blue3', 'surrogate': False, 'teamNumber': 4173}],
#    'tournamentLevel': 'Qualification'},
#   {'description': 'Qualification 2',
#    'field': 'Primary',
#    'matchNumber': 2,
#    'startTime': '2017-04-06T14:07:00',
#    'teams': [{'station': 'Red1', 'surrogate': False, 'teamNumber': 5975},
#     {'station': 'Red2', 'surrogate': False, 'teamNumber': 4915},
#     {'station': 'Red3', 'surrogate': False, 'teamNumber': 957},
#     {'station': 'Blue1', 'surrogate': False, 'teamNumber': 4911},
# ...

# %%
sched["Schedule"][0]["teams"][0]["teamNumber"]
# Out:
# 2910

# %%
len(sched["Schedule"])
# Out:
# 128

# %%
res = json.loads(smf.match_results("pncmp", "2017", "1"))
res
# Out:
# {'Matches': [{'actualStartTime': '2017-04-06T13:55:15.3266667',
#    'description': 'Qualification 1',
#    'matchNumber': 1,
#    'postResultTime': '2017-04-06T13:58:02.4266667',
#    'scoreBlueAuto': 15,
#    'scoreBlueFinal': 285,
#    'scoreBlueFoul': 0,
#    'scoreRedAuto': 15,
#    'scoreRedFinal': 317,
#    'scoreRedFoul': 0,
#    'teams': [{'dq': False, 'station': 'Red1', 'teamNumber': 2910},
#     {'dq': False, 'station': 'Red2', 'teamNumber': 753},
#     {'dq': False, 'station': 'Red3', 'teamNumber': 488},
#     {'dq': False, 'station': 'Blue1', 'teamNumber': 4513},
#     {'dq': False, 'station': 'Blue2', 'teamNumber': 5295},
#     {'dq': False, 'station': 'Blue3', 'teamNumber': 4173}],
#    'tournamentLevel': 'Qualification'}]}

# %%
res["Matches"][0]["scoreBlueFinal"]
# Out:
# 285

# %%
scores = json.loads(smf.match_scores("pncmp", "2017"))
scores
# Out:
# {'MatchScores': [{'alliances': [{'adjustPoints': 0,
#      'alliance': 'Blue',
#      'autoFuelHigh': 0,
#      'autoFuelLow': 0,
#      'autoFuelPoints': 0,
#      'autoMobilityPoints': 15,
#      'autoPoints': 15,
#      'autoRotorPoints': 0,
#      'foulCount': 0,
#      'foulPoints': 0,
#      'kPaBonusPoints': 0,
#      'kPaRankingPointAchieved': False,
#      'robot1Auto': 'Mobility',
#      'robot2Auto': 'Mobility',
#      'robot3Auto': 'Mobility',
#      'rotor1Auto': False,
#      'rotor1Engaged': True,
#      'rotor2Auto': False,
#      'rotor2Engaged': True,
#      'rotor3Engaged': True,
#      'rotor4Engaged': False,
#      'rotorBonusPoints': 0,
#      'rotorRankingPointAchieved': False,
#      'techFoulCount': 0,
#      'teleopFuelHigh': 0,
#      'teleopFuelLow': 0,
#      'teleopFuelPoints': 0,
#      'teleopPoints': 270,
#      'teleopRotorPoints': 120,
#      'teleopTakeoffPoints': 150,
#      'totalPoints': 285,
#      'touchpadFar': 'ReadyForTakeoff',
# ...

# %%
len(scores["MatchScores"])
# Out:
# 128

# %%
scores["MatchScores"][0]["alliances"][0]["teleopPoints"]
# Out:
# 270
