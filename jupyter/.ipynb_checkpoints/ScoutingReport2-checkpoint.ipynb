# %% [markdown]
# ## Notebook Setup

# %% [markdown]
# ### Imports
# * **Run this cell immediately after opening the notebook by placing the cursor in the cell and hitting `SHIFT + ENTER`.**
# * Otherwise, leave this cell alone

# %%
# Imports for telling Python where to find IRScout Python modules
import sys
import os
import re
sys.path.append('..\\Server')
    
# Set Current working directory to irsScouting2017\\Server
ptn = re.compile("jupyter$")
if ptn.search(os.getcwd()) is not None:
    os.chdir("..\\Server")
os.getcwd()

# IRScout Python Modules
import scouting.output as out
from scouting.event import EventDal

# Use the Bokeh plotting package
import bkcharts as bc
import bkcharts.attributes as bca
os.environ["BOKEH_RESOURCES"] = "inline"
bc.output_notebook()

# Other useful modules
import pandas as pd
import sqlalchemy as sa

# Get a database connection
connection_string = ('postgresql://irs1318:irs1318'
                     '@localhost:5432/scouting')
engine = sa.create_engine(connection_string)
conn = engine.connect()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a5dcd5ec-b7f6-4b20-9d74-ae2ff0e3d571">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Set Defaults
# ### Set Event
# * **Next, set `current_event` to the applicable FIRST API event code and run this cell.**

# %%
# Set Chart Size
bc.defaults.height = 300
bc.defaults.width = 1200

# Set Current Event
current_event = "turing"
EventDal.set_current_event(current_event)
EventDal.get_current_event()
# Out:
# 'turing'

# %% [markdown]
# ### Export Excel Ranking File
# * Run this cell to export the rankings spreadsheet.

# %%
fpath = out.get_Path("Report")
out.get_report(fpath)

# %% [markdown]
# ### Get a Dataframe Containing all Measures

# %%
# Get Measures Dataframe
sql_measures = sa.text(
    "SELECT events.name AS event, matches.name AS match, levels.name AS level, dates.name AS date, "
    "teams.name AS team, alliances.name AS alliance, "
    "stations.name AS station, phases.name AS phase, actors.name AS actor, tasks.name AS task, "
    "measures.capability AS capability, measures.successes as successes, measures.attempts AS attempts, "
    "measures.cycle_times as cycle_times, measuretypes.name AS measuretype, reasons.name AS reason, "
    "attempts.name AS attempt "
    "FROM ((((((((((((measures FULL OUTER JOIN teams ON measures.team_id=teams.id) "
    "LEFT JOIN events ON measures.event_id=events.id) "
    "LEFT JOIN matches ON measures.match_id=matches.id) "
    "LEFT JOIN levels ON measures.level_id=levels.id) "
    "LEFT JOIN dates ON measures.date_id=dates.id) "
    "LEFT JOIN alliances ON measures.alliance_id=alliances.id) "
    "LEFT JOIN stations ON measures.station_id=stations.id) "
    "LEFT JOIN phases ON measures.phase_id=phases.id) "
    "LEFT JOIN actors ON measures.actor_id=actors.id) "
    "LEFT JOIN tasks ON measures.task_id=tasks.id) "
    "LEFT JOIN reasons ON measures.reason_id=reasons.id) "
    "LEFT JOIN measuretypes ON measures.measuretype_id=measuretypes.id) "
    "LEFT JOIN attempts ON measures.attempt_id=attempts.id "
    "WHERE events.name='" + current_event + "';")
measures = pd.read_sql(sql_measures, conn)
measures.query("task == 'shootHighBoiler'").query("phase == 'auto' or phase == 'teleop'")
#measures.query("task == 'climbRope' and phase == 'finish'")"
# Out:
#        event  match level                 date  team alliance station   phase  \
# 9     turing  002-q  qual  2017-04-20T08:38:00  2990     blue       3    auto
# 84    turing  005-q  qual  2017-04-20T09:02:00  1165      red       3    auto
# 128   turing  004-q  qual  2017-04-20T08:54:00   108     blue       2  teleop
# 217   turing  006-q  qual  2017-04-20T09:10:00  1595     blue       2    auto
# 5013  turing  107-q  qual  2017-04-21T17:40:00  3937      red       3  teleop
# 5117  turing  105-q  qual  2017-04-21T17:24:00  2352     blue       3    auto
# 5125  turing  102-q  qual  2017-04-21T17:00:00  3019     blue       1    auto
# 5137  turing  102-q  qual  2017-04-21T17:00:00  2761      red       3    auto
# 5156  turing  107-q  qual  2017-04-21T17:40:00  3476     blue       1  teleop
# 5197  turing  102-q  qual  2017-04-21T17:00:00  3019     blue       1  teleop
# 5204  turing  104-q  qual  2017-04-21T17:16:00  4586     blue       3    auto
# 5208  turing  103-q  qual  2017-04-21T17:08:00  2046      red       1    auto
# 5234  turing  107-q  qual  2017-04-21T17:40:00  3937      red       3    auto
# 5344  turing  109-q  qual  2017-04-21T17:56:00  6384      red       3    auto
# 5367  turing  110-q  qual  2017-04-21T18:04:00  3219     blue       1    auto
# 5407  turing  109-q  qual  2017-04-21T17:56:00  1323     blue       3  teleop
# 5414  turing  112-q  qual  2017-04-21T18:20:00  2102      red       2    auto
# 5424  turing  111-q  qual  2017-04-21T18:12:00    16     blue       1    auto
# 5426  turing  111-q  qual  2017-04-21T18:12:00    16     blue       1  teleop
# 5433  turing  109-q  qual  2017-04-21T17:56:00  1323     blue       3    auto
#
#       actor             task  capability  successes  attempts  cycle_times  \
# 9     robot  shootHighBoiler           0          0         0            0
# 84    robot  shootHighBoiler           0          1         1            0
# 128   robot  shootHighBoiler           0          1        10            0
# 217   robot  shootHighBoiler           0          1         1            0
# 295   robot  shootHighBoiler           0          0         4            0
# 368   robot  shootHighBoiler           0          0         1            0
# 382   robot  shootHighBoiler           0         10        10            0
# 399   robot  shootHighBoiler           0          1         9            0
# 413   robot  shootHighBoiler           0         14        14            0
# 448   robot  shootHighBoiler           0         22        22            0
# 462   robot  shootHighBoiler           0          7        10            0
# 463   robot  shootHighBoiler           0         17        26            0
# 486   robot  shootHighBoiler           0         16        36            0
# 487   robot  shootHighBoiler           0          0         2            0
# 496   robot  shootHighBoiler           0          0        10            0
# 529   robot  shootHighBoiler           0          1         1            0
# 559   robot  shootHighBoiler           0          0         0            0
# 566   robot  shootHighBoiler           0          1         1            0
# 567   robot  shootHighBoiler           0          0         8            0
# 568   robot  shootHighBoiler           0          1         1            0
# 620   robot  shootHighBoiler           0          4        10            0
# 623   robot  shootHighBoiler           0         85        96            0
# 640   robot  shootHighBoiler           0          0         0            0
# 673   robot  shootHighBoiler           0         11        21            0
# 774   robot  shootHighBoiler           0          0        10            0
# 843   robot  shootHighBoiler           0         35        35            0
# 891   robot  shootHighBoiler           0         24        24            0
# 916   robot  shootHighBoiler           0          1         6            0
# 959   robot  shootHighBoiler           0         14        19            0
# 1058  robot  shootHighBoiler           0          3         9            0
# ...     ...              ...         ...        ...       ...          ...
# 4630  robot  shootHighBoiler           0         81        94            0
# 4646  robot  shootHighBoiler           0          0        10            0
# 4661  robot  shootHighBoiler           0          7        12            0
# 4694  robot  shootHighBoiler           0          3        10            0
# 4724  robot  shootHighBoiler           0          2         9            0
# 4740  robot  shootHighBoiler           0          7        10            0
# 4761  robot  shootHighBoiler           0          2         4            0
# 4778  robot  shootHighBoiler           0          5         5            0
# 4783  robot  shootHighBoiler           0          8        10            0
# 4799  robot  shootHighBoiler           0          0        10            0
# 4864  robot  shootHighBoiler           0         14        20            0
# 4891  robot  shootHighBoiler           0          5         7            0
# 4912  robot  shootHighBoiler           0          4        10            0
# 4946  robot  shootHighBoiler           0         18        30            0
# 5013  robot  shootHighBoiler           0         28        42            0
# 5117  robot  shootHighBoiler           0         15        25            0
# 5125  robot  shootHighBoiler           0          1         4            0
# 5137  robot  shootHighBoiler           0          0         5            0
# 5156  robot  shootHighBoiler           0          6         9            0
# 5197  robot  shootHighBoiler           0          2         2            0
# 5204  robot  shootHighBoiler           0          3        10            0
# 5208  robot  shootHighBoiler           0          7        10            0
# 5234  robot  shootHighBoiler           0          2        10            0
# 5344  robot  shootHighBoiler           0          0        10            0
# 5367  robot  shootHighBoiler           0          0         3            0
# 5407  robot  shootHighBoiler           0         26        36            0
# 5414  robot  shootHighBoiler           0          3         3            0
# 5424  robot  shootHighBoiler           0         13        23            0
# 5426  robot  shootHighBoiler           0         79        89            0
# 5433  robot  shootHighBoiler           0         23        36            0
#
#      measuretype reason  attempt
# 9          count     na  summary
# 84         count     na  summary
# 128        count     na  summary
# 217        count     na  summary
# 295        count     na  summary
# 368        count     na  summary
# 382        count     na  summary
# 399        count     na  summary
# 413        count     na  summary
# 448        count     na  summary
# 462        count     na  summary
# 463        count     na  summary
# 486        count     na  summary
# 487        count     na  summary
# 496        count     na  summary
# 529        count     na  summary
# 559        count     na  summary
# 566        count     na  summary
# 567        count     na  summary
# 568        count     na  summary
# 620        count     na  summary
# 623        count     na  summary
# 640        count     na  summary
# 673        count     na  summary
# 774        count     na  summary
# 843        count     na  summary
# 891        count     na  summary
# 916        count     na  summary
# 959        count     na  summary
# 1058       count     na  summary
# ...          ...    ...      ...
# 4630       count     na  summary
# 4646       count     na  summary
# 4661       count     na  summary
# 4694       count     na  summary
# 4724       count     na  summary
# 4740       count     na  summary
# 4761       count     na  summary
# 4778       count     na  summary
# 4783       count     na  summary
# 4799       count     na  summary
# 4864       count     na  summary
# 4891       count     na  summary
# 4912       count     na  summary
# 4946       count     na  summary
# 5013       count     na  summary
# 5117       count     na  summary
# 5125       count     na  summary
# 5137       count     na  summary
# 5156       count     na  summary
# 5197       count     na  summary
# 5204       count     na  summary
# 5208       count     na  summary
# 5234       count     na  summary
# 5344       count     na  summary
# 5367       count     na  summary
# 5407       count     na  summary
# 5414       count     na  summary
# 5424       count     na  summary
# 5426       count     na  summary
# 5433       count     na  summary
#
# [176 rows x 17 columns]

# %% [markdown]
# ### Get Number of Completed Matches"

# %%
# Set recent_matches to n to filter out all but the last n matches.
recent_matches= 12

select_recent_matches = sa.text(
    "with current AS (SELECT s.event, s.match, date from schedules sched, "
    "status s WHERE sched.event = s.event "
    "AND sched.match = s.match limit 1 ) "


    "SELECT * FROM ( "
    "SELECT row_number() over (partition by team order by sched.date desc) as r, "
    " sched.* from schedules sched, current c WHERE sched.event = c.event and sched.date <= c.date )"
    " row_schedule WHERE row_schedule.r <= " + str(
        recent_matches) + " ORDER by team, date desc")
df = pd.read_sql(select_recent_matches, conn)
num_matches = df[['team', 'level']].groupby('team').count()
num_matches.columns = ['matches']

# %% [markdown]
# ### Create and Save Gears Chart
# * This cell creates the gears chart and saves it to Server/web/data as a static, interactive html file.
#
# **TODO:** Add an event code and timestamp to gears chart file name.

# %%
# Create summary data frame for placing gears
gears_df = measures.query("task == 
...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='a29575b3-890b-488a-9d7d-c7cb3db02951', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='b0973239-f71a-477f-9903-212d8605d7d0', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='b927c677-dd3b-4925-95ce-19ef2c62c46b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='bcb26cfd-9b8d-42d2-9e8e-b4c78e9cb8dc', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='bcc6c4b1-96e3-4876-bc6b-d53a66b0b023', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='bfba511c-139a-4995-8c14-9207c9b8822d', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='bfe05cdc-1e75-485b-969f-a45021802b12', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='c04c92af-2a5d-48d5-afb8-d145306b94df', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='c5235f1e-33c5-4d34-83eb-84088887d3d4', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='c54fd556-ea6c-440d-a95c-1a102ab8cdd3', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d05c525b-d93d-4c8d-a1b3-8cb534fbddc4', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d08d6e2d-f8c8-4a64-b94a-7d0506e97c83', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d295d52d-37ce-4721-8736-d7cf6925d8df', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d6478b2e-0677-4b8d-bded-8e87e3916252', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d731e3e0-b6c6-45d9-bcb5-cf58bcb89dd8', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d8f2447f-752f-4fe5-8781-bc4f8c0d1585', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='d972b9b5-8206-4276-b65e-3d5c4bcfdcdf', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e1ba7b39-066f-40fd-9f69-b1bd74f03a4e', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e25c4a8a-4b3f-454b-9c0b-da641920ef60', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e527bddc-e715-4810-90e9-4b23ed83e425', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='e998f90f-1994-4dbb-9669-df74f4367f4b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='ec7123f4-286d-4c1f-8888-e3a83729d16f', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='f2133835-6fc4-4870-a58b-051cd76d87a2', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='ff404cb0-52dd-4180-a316-4214f28330e6', ...)

# %%
# Create summary data frame for climbing rope
climbs_df = measures.query("task == 'climbRope'").query("phase == 'finish'").groupby('team').count()
climbs_df['average'] = climbs_df['successes'] / num_matches['matches']
climbs_df = climbs_df.sort_values('average', ascending = False)

# Create gears chart in Bokeh
climb_chart = bc.Bar(climbs_df, values = 'average', label = bca.cat(sort = False), legend = None, color = 'DarkGoldenRod',
                   title = 'Total Times Climbed', ylabel = "Times Climbed")
bc.output_file('web/data/climb_chart.html', mode = 'inline')
bc.show(climb_chart)
# Out:
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='04e0854b-df1b-4628-83ca-b8a51a5e284b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='0bf6138f-b845-4769-9057-2f87631bf310', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='0c3d2c47-e04b-47d9-b14a-f6c669f3ab30', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='103fe303-4608-439e-a9aa-80056a487011', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='131d72f8-db8d-44f9-a55e-54e397073c55', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='168a9550-0939-42bf-a21a-6a9f449454b0', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='1b623da4-91ca-40b9-a425-fa2154923f8f', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='1d723c4f-03c2-4f1a-a741-1e43cee1d5bf', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='1ef2557e-ca56-4d82-945a-98d68ec925bf', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='1fb45e6b-2f2f-445b-ae9c-05f3db9d83dd', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='205d5f82-9126-4b6a-9376-d86229ec1f03', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='20ecc66a-24a4-4796-84b8-4db8b5b265cc', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='216bebe2-5f39-4e28-9871-be1775290341', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='290f88f6-e458-4bc1-8d27-417f82daccde', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='303aee16-b6a0-4ee6-87c5-afcd5b9078f4', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='3428b4b7-4362-4f25-9992-e6848ba5dc26', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='34f5aa89-60b0-4e3a-a01f-f27618057927', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='35642587-4841-4be4-9044-219675e2259b', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='369eea4d-3f98-47ad-88ae-b1656b868cea', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='3c4da7e9-0e24-491a-becf-6e0b9940867c', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='3d0e86f0-e14a-4d59-bf85-39cfff29fde2', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='3fa8f45f-a232-44de-bf68-79f69abc3721', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id='41e76cd7-acb2-416b-b4f2-9cda72918dfe', ...)
# E-1010 (CDSVIEW_SOURCE_DOESNT_MATCH): CDSView used by Glyph renderer must have a source that matches the Glyph renderer's data source: GlyphRenderer(id