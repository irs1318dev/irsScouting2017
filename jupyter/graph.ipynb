# %%
import pandas as pd
import psycopg2
import bokeh.plotting
import bokeh.models as bmodels
import bokeh.plotting as plt
import bokeh.palettes as bpalettes
import bokeh.transform as btransform
import bokeh.io

import server.model.connection as smc
import server.model.version as smv
import server.model.event as sme

bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="25fc00d1-e010-4d51-b6f4-129a398cae7d">Loading BokehJS ...</span>
#     </div>

# %%
conn = smc.pool.getconn()

# %%
sme.EventDal.set_current_event("test_data","2019")
sme.EventDal.set_current_match("020-q")
# Out:
# 'current match 020-q'

# %%
sql = '''
    SELECT * FROM vw_measures 
    WHERE task IN ('centerHatch', 'farHatch', 'closeHatch', 'rocketHatch',
    'rocketHatch1', 'rocketHatch2', 'rocketHatch3', 'csHatch');
'''
pd.read_sql(sql, conn)
# Out:
#                     date      event season level  match alliance  team  \
# 0    2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  2557
# 1    2018-03-30T11:30:00  test_data   2019  qual  001-q      red  2926
# 2    2018-03-30T11:30:00  test_data   2019  qual  001-q      red  2926
# 3    2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  1258
# 4    2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  1258
# 5    2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  3684
# 6    2018-03-30T11:30:00  test_data   2019  qual  001-q      red  2926
# 7    2018-03-30T11:30:00  test_data   2019  qual  001-q      red  6350
# 8    2018-03-30T11:30:00  test_data   2019  qual  001-q      red  4918
# 9    2018-03-30T11:30:00  test_data   2019  qual  001-q      red  6350
# 10   2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  3684
# 11   2018-03-30T11:30:00  test_data   2019  qual  001-q      red  6350
# 12   2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  2557
# 13   2018-03-30T11:30:00  test_data   2019  qual  001-q      red  4918
# 14   2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  1258
# 15   2018-03-30T11:30:00  test_data   2019  qual  001-q      red  4918
# 16   2018-03-30T11:30:00  test_data   2019  qual  001-q      red  4918
# 17   2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  3684
# 18   2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  3684
# 19   2018-03-30T11:37:00  test_data   2019  qual  002-q     blue   360
# 20   2018-03-30T11:37:00  test_data   2019  qual  002-q      red  6503
# 21   2018-03-30T11:37:00  test_data   2019  qual  002-q      red  2976
# 22   2018-03-30T11:37:00  test_data   2019  qual  002-q     blue  2942
# 23   2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  2557
# 24   2018-03-30T11:30:00  test_data   2019  qual  001-q      red  2926
# 25   2018-03-30T11:30:00  test_data   2019  qual  001-q      red  6350
# 26   2018-03-30T11:30:00  test_data   2019  qual  001-q     blue  3684
# 27   2018-03-30T11:30:00  test_data   2019  qual  001-q      red  4918
# 28   2018-03-30T11:37:00  test_data   2019  qual  002-q     blue   360
# 29   2018-03-30T11:37:00  test_data   2019  qual  002-q     blue   360
# ..                   ...        ...    ...   ...    ...      ...   ...
# 240  2018-03-30T14:15:00  test_data   2019  qual  016-q     blue  1258
# 241  2018-03-30T14:15:00  test_data   2019  qual  016-q     blue  1258
# 242  2018-03-30T14:15:00  test_data   2019  qual  016-q     blue  1258
# 243  2018-03-30T14:22:00  test_data   2019  qual  017-q     blue  3588
# 244  2018-03-30T14:22:00  test_data   2019  qual  017-q     blue  3588
# 245  2018-03-30T14:22:00  test_data   2019  qual  017-q     blue  3684
# 246  2018-03-30T14:22:00  test_data   2019  qual  017-q      red  6503
# 247  2018-03-30T14:29:00  test_data   2019  qual  018-q     blue  5937
# 248  2018-03-30T14:29:00  test_data   2019  qual  018-q      red  3786
# 249  2018-03-30T14:36:00  test_data   2019  qual  019-q     blue  2046
# 250  2018-03-30T14:36:00  test_data   2019  qual  019-q      red  1778
# 251  2018-03-30T14:43:00  test_data   2019  qual  020-q      red  4131
# 252  2018-03-30T14:36:00  test_data   2019  qual  019-q      red  1778
# 253  2018-03-30T14:36:00  test_data   2019  qual  019-q     blue  1425
# 254  2018-03-30T14:36:00  test_data   2019  qual  019-q      red  2557
# 255  2018-03-30T14:43:00  test_data   2019  qual  020-q     blue  4918
# 256  2018-03-30T14:43:00  test_data   2019  qual  020-q     blue  4918
# 257  2018-03-30T14:43:00  test_data   2019  qual  020-q      red  4131
# 258  2018-03-30T14:43:00  test_data   2019  qual  020-q     blue  2976
# 259  2018-03-30T14:43:00  test_data   2019  qual  020-q     blue  2976
# 260  2018-03-30T14:36:00  test_data   2019  qual  019-q     blue  2927
# 261  2018-03-30T14:43:00  test_data   2019  qual  020-q      red  4131
# 262  2018-03-30T14:43:00  test_data   2019  qual  020-q      red  4131
# 263  2018-03-30T14:43:00  test_data   2019  qual  020-q      red  1258
# 264  2018-03-30T14:43:00  test_data   2019  qual  020-q      red  3786
# 265  2018-03-30T14:43:00  test_data   2019  qual  020-q      red  3786
# 266  2018-03-30T14:43:00  test_data   2019  qual  020-q     blue  4461
# 267  2018-03-30T14:43:00  test_data   2019  qual  020-q     blue  4461
# 268  2018-03-30T14:43:00  test_data   2019  qual  020-q      red  1258
# 269  2018-03-30T14:43:00  test_data   2019  qual  020-q      red  1258
#
#     station  actor          task measuretype   phase  attempt reason  \
# 0         2  robot      farHatch     boolean    auto  summary     na
# 1         1  robot   centerHatch     boolean    auto  summary     na
# 2         1  robot      farHatch     boolean    auto  summary     na
# 3         1  robot   centerHatch     boolean    auto  summary     na
# 4         1  robot    closeHatch     boolean    auto  summary     na
# 5         3  robot    closeHatch     boolean    auto  summary     na
# 6         1  robot   rocketHatch     boolean    auto  summary     na
# 7         2  robot      farHatch     boolean    auto  summary     na
# 8         3  robot    closeHatch     boolean    auto  summary     na
# 9         2  robot       csHatch       count  teleop  summary     na
# 10        3  robot       csHatch       count  teleop  summary     na
# 11        2  robot  rocketHatch3       count  teleop  summary     na
# 12        2  robot  rocketHatch1       count  teleop  summary     na
# 13        3  robot       csHatch       count  teleop  summary     na
# 14        1  robot  rocketHatch1       count  teleop  summary     na
# 15        3  robot  rocketHatch3       count  teleop  summary     na
# 16        3  robot  rocketHatch2       count  teleop  summary     na
# 17        3  robot  rocketHatch2       count  teleop  summary     na
# 18        3  robot  rocketHatch3       count  teleop  summary     na
# 19        1  robot       csHatch       count  teleop  summary     na
# 20        2  robot  rocketHatch2       count  teleop  summary     na
# 21        1  robot  rocketHatch3       count  teleop  summary     na
# 22        2  robot      farHatch     boolean    auto  summary     na
# 23        2  robot       csHatch       count  teleop  summary     na
# 24        1  robot  rocketHatch3       count  teleop  summary     na
# 25        2  robot  rocketHatch2       count  teleop  summary     na
# 26        3  robot  rocketHatch1       count  teleop  summary     na
# 27        3  robot  rocketHatch1       count  teleop  summary     na
# 28        1  robot  rocketHatch2       count  teleop  summary     na
# 29        1  robot      farHatch     boolean    auto  summary     na
# ..      ...    ...           ...         ...     ...      ...    ...
# 240       1  robot  rocketHatch1       count  teleop  summary     na
# 241       1  robot  rocketHatch2       count  teleop  summary     na
# 242       1  robot  rocketHatch3       count  teleop  summary     na
# 243       2  robot    closeHatch     boolean    auto  summary     na
# 244       2  robot  rocketHatch1       count  teleop  summary     na
# 245       3  robot  rocketHatch1       count  teleop  summary     na
# 246       2  robot  rocketHatch1       count  teleop  summary     na
# 247       1  robot       csHatch       count  teleop  summary     na
# 248       3  robot  rocketHatch3       count  teleop  summary     na
# 249       2  robot  rocketHatch2       count  teleop  summary     na
# 250       3  robot  rocketHatch3       count  teleop  summary     na
# 251       1  robot       csHatch       count  teleop  summary     na
# 252       3  robot       csHatch       count  teleop  summary     na
# 253       3  robot  rocketHatch1       count  teleop  summary     na
# 254       2  robot  rocketHatch1       count  teleop  summary     na
# 255       1  robot    closeHatch     boolean    auto  summary     na
# 256       1  robot  rocketHatch1       count  teleop  summary     na
# 257       1  robot  rocketHatch1       count  teleop  summary     na
# 258       3  robot       csHatch       count  teleop  summary     na
# 259       3  robot  rocketHatch1       count  teleop  summary     na
# 260       1  robot    closeHatch     boolean    auto  summary     na
# 261       1  robot  rocketHatch2       count  teleop  summary     na
# 262       1  robot  rocketHatch3       count  teleop  summary     na
# 263       3  robot       csHatch       count  teleop  summary     na
# 264       2  robot  rocketHatch3       count  teleop  summary     na
# 265       2  robot       csHatch       count  teleop  summary     na
# 266       2  robot       csHatch       count  teleop  summary     na
# 267       2  robot  rocketHatch3       count  teleop  summary     na
# 268       3  robot  rocketHatch2       count  teleop  summary     na
# 269       3  robot  rocketHatch3       count  teleop  summary     na
#
#     capability  successes  attempts  cycle_times  last_match
# 0         None          1         1            0           4
# 1         None          0         0            0           3
# 2         None          0         0            0           3
# 3         None          1         1            0           4
# 4         None          1         1            0           4
# 5         None          0         0            0           3
# 6         None          1         1            0           3
# 7         None          0         0            0           3
# 8         None          0         0            0           4
# 9         None          2         2            0           3
# 10        None          2         2            0           3
# 11        None          2         2            0           3
# 12        None          1         1            0           4
# 13        None          2         2            0           4
# 14        None          2         2            0           4
# 15        None          0         0            0           4
# 16        None          1         1            0           4
# 17        None          3         3            0           3
# 18        None          0         0            0           3
# 19        None          4         4            0           3
# 20        None          3         3            0           3
# 21        None          1         1            0           4
# 22        None          1         1            0           4
# 23        None          2         2            0           4
# 24        None          3         3            0           3
# 25        None          2         2            0           3
# 26        None          3         3            0           3
# 27        None          1         1            0           4
# 28        None          3         3            0           3
# 29        None          1         1            0           3
# ..         ...        ...       ...          ...         ...
# 240       None          2         2            0           2
# 241       None          1         1            0           2
# 242       None          1         1            0           2
# 243       None          1         1            0           1
# 244       None          3         3            0           1
# 245       None          3         3            0           1
# 246       None          2         2            0           1
# 247       None          1         1            0           1
# 248       None          1         1            0           2
# 249       None          3         3            0           1
# 250       None          1         1            0           1
# 251       None          1         1            0           1
# 252       None          0         0            0           1
# 253       None          3         3            0           1
# 254       None          2         2            0           1
# 255       None          1         1            0           1
# 256       None          1         1            0           1
# 257       None          1         1            0           1
# 258       None          1         1            0           1
# 259       None          3         3            0           1
# 260       None          1         1            0           1
# 261       None          2         2            0           1
# 262       None          0         0            0           1
# 263       None          1         1            0           1
# 264       None          0         0            0           1
# 265       None          2         2            0           1
# 266       None          2         2            0           1
# 267       None          1         1            0           1
# 268       None          3         3            0           1
# 269       None          1         1            0           1
#
# [270 rows x 19 columns]

# %%
match = '020-q'
alliance = 'red'
sql = '''
    SELECT team, alliance FROM schedules
        INNER JOIN status ON schedules.event_id=status.event_id 
    WHERE schedules.event_id=status.event_id AND schedules.match=%s AND alliance=%s;

'''
pd.read_sql(sql, conn, params=[match, alliance])
# Out:
#    team alliance
# 0  3786      red
# 1  4131      red
# 2  1258      red

# %%
match = '020-q'
alliance = 'red'
sql = '''
    SELECT team, task, SUM(successes) AS hatches_placed FROM vw_measures 
    WHERE task IN ('centerHatch', 'farHatch', 'closeHatch', 'rocketHatch',
    'rocketHatch1', 'rocketHatch2', 'rocketHatch3', 'csHatch')
    AND team IN (SELECT team FROM schedules
                 INNER JOIN status ON schedules.event_id=status.event_id 
                 WHERE schedules.event_id=status.event_id AND schedules.match=%s
                 AND alliance=%s)
    GROUP BY team, task;
'''
pd.read_sql(sql, conn, params=[match, alliance])
# Out:
#     team          task  hatches_placed
# 0   1258   centerHatch               1
# 1   1258    closeHatch               1
# 2   1258       csHatch               6
# 3   1258  rocketHatch1               7
# 4   1258  rocketHatch2               4
# 5   1258  rocketHatch3               2
# 6   3786       csHatch               6
# 7   3786   rocketHatch               1
# 8   3786  rocketHatch1               1
# 9   3786  rocketHatch3               1
# 10  4131       csHatch               8
# 11  4131   rocketHatch               1
# 12  4131  rocketHatch1               3
# 13  4131  rocketHatch2               3
# 14  4131  rocketHatch3               1

# %%
match = '020-q'
alliance = 'red'
sql = '''
    SELECT team, SUM(successes) AS hatches_placed, SUM(attempts) AS attempts FROM vw_measures 
    WHERE task IN ('centerHatch', 'farHatch', 'closeHatch', 'rocketHatch',
    'rocketHatch1', 'rocketHatch2', 'rocketHatch3', 'csHatch')
    AND team IN (SELECT team FROM schedules
                 INNER JOIN status ON schedules.event_id=status.event_id 
                 WHERE schedules.event_id=status.event_id AND schedules.match=%s
                 AND alliance=%s)
    GROUP BY team;
'''
df_temp = pd.read_sql(sql, conn, params=[match, alliance])
df_redHatches = df_temp.set_index('team')
df_redHatches
# Out:
#       hatches_placed  attempts
# team
# 1258              21        21
# 3786               9         9
# 4131              16        16

# %%
match = '020-q'
alliance = 'blue'
sql = '''
    SELECT team, SUM(successes) AS hatches_placed, SUM(attempts) AS attempts FROM vw_measures 
    WHERE task IN ('centerHatch', 'farHatch', 'closeHatch', 'rocketHatch',
    'rocketHatch1', 'rocketHatch2', 'rocketHatch3', 'csHatch')
    AND team IN (SELECT team FROM schedules
                 INNER JOIN status ON schedules.event_id=status.event_id 
                 WHERE schedules.event_id=status.event_id AND schedules.match=%s
                 AND alliance=%s)
    GROUP BY team;
'''
df_temp = pd.read_sql(sql, conn, params=[match, alliance])
df_blueHatches = df_temp.set_index('team')
df_blueHatches
# Out:
#       hatches_placed  attempts
# team
# 2976              15        15
# 4461               9         9
# 4918              13        13

# %%
df_rHatches = df_redHatches.T
df_rHatches
# Out:
# team            1258  3786  4131
# hatches_placed    21     9    16
# attempts          21     9    16

# %%
df_rHatches.index.name

# %%
rHatches_cds = bmodels.ColumnDataSource(df_rHatches)
rHatches_cds.column_names
# Out:
# ['1258', '3786', '4131', 'index']

# %%
rteams = rHatches_cds.column_names[:3]
rteams
# Out:
# ['1258', '3786', '4131']

# %%
p = plt.figure(title='Hatches Placed', x_range=rHatches_cds.data['index'], 
              plot_width=700, plot_height=350)
p.vbar_stack(rteams, x='index', width=0.8, 
            source=rHatches_cds, color=bpalettes.Reds3, legend=[" " + x for x in rteams])

bokeh.io.show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3b983311-37b7-43ed-a95f-1a3758d614e7"></div>
# </div>

# %%
df_bHatches = df_blueHatches.T
df_bHatches
# Out:
# team            2976  4461  4918
# hatches_placed    15     9    13
# attempts          15     9    13

# %%
bHatches_cds = bmodels.ColumnDataSource(df_bHatches)
bHatches_cds.column_names
# Out:
# ['2976', '4461', '4918', 'index']

# %%
bteams = bHatches_cds.column_names[1:]
bteams
# Out:
# ['4461', '4918', 'index']

# %%
p = plt.figure(title='Hatches Placed', x_range=bHatches_cds.data['index'], 
              plot_width=700, plot_height=350)
p.vbar_stack(bteams, x='index', width=0.8, 
            source=bHatches_cds, color=bpalettes.Blues3, legend=[" " + x for x in bteams])

bokeh.io.show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3cbefbac-51c5-47ec-bdc0-e1fc630d1238"></div>
# </div>

# %%
p = plt.figure(title='Hatches Placed', x_range=['hatches_placed', 'attempts'], 
              plot_width=700, plot_height=350)
p.vbar_stack(bteams, x=btransform.dodge('index',  0.25,  range=p.x_range), width=0.4, 
            source=bHatches_cds, color=bpalettes.Blues3, legend=[" " + x for x in bteams])
p.vbar_stack(rteams, x=btransform.dodge('index',  -0.25,  range=p.x_range), width=0.4, 
            source=rHatches_cds, color=bpalettes.Reds3, legend=[" " + x for x in rteams])

bokeh.io.show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="3756bab8-58a2-4327-88ba-3b764b8a5566"></div>
# </div>
