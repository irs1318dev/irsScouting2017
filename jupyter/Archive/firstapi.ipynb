# %%
import json
import server.model.firstapi as smf

# %%
json.loads(smf.events("2018"))  # "WEEK0" is valid event code.
# Out:
# {'Events': [{'address': '#10, 7555 Falconridge Blvd NE',
#    'city': 'Calgary',
#    'code': 'ABCA',
#    'country': 'Canada',
#    'dateEnd': '2018-04-07T23:59:59',
#    'dateStart': '2018-04-04T00:00:00',
#    'districtCode': None,
#    'divisionCode': None,
#    'name': 'Canadian Rockies Regional',
#    'stateprov': 'AB',
#    'timezone': 'Mountain Standard Time',
#    'type': 'Regional',
#    'venue': 'Genesis Centre',
#    'webcasts': [],
#    'website': 'http://frcwest.com/'},
#   {'address': '700 Monroe Street SW',
#    'city': 'Huntsville',
#    'code': 'ALHU',
#    'country': 'USA',
#    'dateEnd': '2018-03-17T23:59:59',
#    'dateStart': '2018-03-14T00:00:00',
#    'districtCode': None,
#    'divisionCode': None,
#    'name': 'Rocket City Regional',
#    'stateprov': 'AL',
#    'timezone': 'Central Standard Time',
#    'type': 'Regional',
#    'venue': 'Von Braun Center',
#    'webcasts': ['https://www.twitch.tv/firstinspires9',
# ...

# %%
json.loads(smf.match_scores("WEEK0", "2018"))
# Out:
# {'MatchScores': [{'alliances': [{'adjustPoints': 0,
#      'alliance': 'Blue',
#      'autoOwnershipPoints': 0,
#      'autoPoints': 0,
#      'autoQuestRankingPoint': False,
#      'autoRobot1': 'None',
#      'autoRobot2': 'None',
#      'autoRobot3': 'None',
#      'autoRunPoints': 0,
#      'autoScaleOwnershipSec': 0,
#      'autoSwitchAtZero': False,
#      'autoSwitchOwnershipSec': 0,
#      'endgamePoints': 30,
#      'endgameRobot1': 'Levitate',
#      'endgameRobot2': 'None',
#      'endgameRobot3': 'None',
#      'faceTheBossRankingPoint': False,
#      'foulCount': 0,
#      'foulPoints': 0,
#      'rp': 2,
#      'techFoulCount': 0,
#      'teleopOwnershipPoints': 210,
#      'teleopPoints': 265,
#      'teleopScaleBoostSec': 0,
#      'teleopScaleForceSec': 0,
#      'teleopScaleOwnershipSec': 90,
#      'teleopSwitchBoostSec': 0,
#      'teleopSwitchForceSec': 0,
#      'teleopSwitchOwnershipSec': 120,
#      'totalPoints': 265,
#      'vaultBoostPlayed': 0,
# ...

# %%
import numpy.random

# %%
numpy.random.binomial(1, .05, 1)
# Out:
# array([0])
